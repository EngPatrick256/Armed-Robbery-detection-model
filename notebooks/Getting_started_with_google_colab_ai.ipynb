# %% [markdown]
# <a href="https://colab.research.google.com/github/EngPatrick256/Armed-Robbery-detection-model/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.40 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.1/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="W3X8te0EtasOlwKfOTl1")
project = rf.workspace("robbery").project("robbery-activity")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Robbery-Activity-1 in yolo26:: 100%|██████████| 16411/16411 [00:02<00:00, 7685.52it/s]

# %%
# !yolo detect train \
data=/content/Robbery-Activity-1/data.yaml \
model=yolo26s.pt \
epochs=100 \
imgsz=640 \
batch=-1 \
patience=50 \
optimizer=auto \
pretrained=True \
cache=True
# Out:
# ...
# Ultralytics 8.4.40 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
